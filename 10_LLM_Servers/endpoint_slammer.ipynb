# %% [markdown]
# Now that you've deployed your endpoint - it's time to slam it!

# %%
import os
import getpass
from dotenv import load_dotenv

load_dotenv()

if not os.environ.get("FIREWORKS_API_KEY"):
    os.environ["FIREWORKS_API_KEY"] = getpass.getpass("Enter your Fireworks API key: ")

# %% [markdown]
# Let's try with 1 request, just to verify our endpoint is alive.
#
# Make sure you provide your own endpoint identifier! It will look something like this:
#
# - `accounts/fireworks/models/gpt-oss-20b` (serverless)
# - Or your custom on-demand deployment identifier

# %%
from langchain_fireworks import ChatFireworks

# REPLACE WITH YOUR OWN ENDPOINT IDENTIFIER
model_endpoint = "accounts/katexxi/deployments/xt382bfe"

llm = ChatFireworks(model=model_endpoint)

response = llm.invoke("How much wood could a wood chuck chuck if a wood chuck could chuck wood?")
print(response.content)
# Out:
# It’s a classic tongue‑twister, but scientists have wittier answers than a tongue‑twist‑machine!
# A 1988 article in *The American Naturalist* asked, “If a woodchuck could chuck wood, how much wood could it chuck?” The answer was no more than a *mammoth*‑sized pile of… **dirt**—and then inventors converted that to wood.
#
# **The math starts with burrows.**
# - A woodchuck moves about **700 lb** of soil each time it digs its burrow.
# - That’s roughly **35 cubic yards of loam** (or about 24 cubic meters).
#
# **Convert to wood.**
# - If you were to replace that loam with hardwood, say *blue‑legged spruce* at 500 lb per cubic yard, the wood‑equivalent would be about **35 cubic yards × 500 lb/yard³ ≈ 17,500 lb**.
#
# So, in a tongue‑twisting, tongue‑slur‑worthy sense, a woodchuck *could chuck* **on the order of 10 000–20 000 pounds** of wood—if it even had thumbs to swing its pickaxe!
#
# In short:
# - **Real answer**: ~700 lb of *dirt* (the burrowing equivalent)
# - **Woodchuck‑style answer**: ≈10 000–20 000 lb of *wood* (if it had the right tools).
#
# So the next time you hear the rhyme, you can say: “He’s not just a wood‑chuck; he’s a wood‑**chuck‑weight‑lifting** champ with the mathematics to prove it!”

# %% [markdown]
# Now, let's SLAM IT.

# %%
import asyncio

async def send_request(llm, idx):
    try:
        response = await llm.ainvoke(
            f"How much wood could a wood chuck chuck if a wood chuck could chuck wood? (Request {idx})"
        )
        print(f"Response {idx}: {response.content[:60]}...")
    except Exception as e:
        print(f"Request {idx} failed: {e}")

async def main():
    tasks = [send_request(llm, i) for i in range(1, 25)]
    await asyncio.gather(*tasks)

await main()
# Out:
# Response 11: The old tongue‐twister answer says: **“A woodchuck would chu...
# Response 18: A classic tongue‑teller, indeed! While woodchucks (groundhog...
# Response 15: Sorry, I do not have information for that....
# Response 1: The classic tongue‑twister has no real scientific answer—woo...
# Response 8: The classic tongue‑twister doesn’t actually give us a concre...
# Response 6: The classic tongue‑twister answer is pretty much: **“A woodc...
# Response 17: **Answer (Request 17)**
#
# > **"A wood‐chuck would chuck as mu...
# Response 13: **Classic tongue‑twister answer**
#
# > “A woodchuck would chuc...
# Response 7: **📸 Meme‑style answer (text‑only version)**
#
# ```
#          ...
# Response 3: A woodchuck could chuck roughly 700 pounds of wood in a day,...
# Response 10: The classic rhyme paints a playful picture of a wood‑chuck (...
# Response 12: Ah, the age‑old riddle that’s been churning tongues since th...
# Response 20: Woodchucks would chuck the maximum of all wood that a woodch...
# Response 14: **Answer (tongue‑twister style, no hard science needed)**
# ...
# Response 9: The classic tongue‑twister’s answer isn’t a hard fact—woodch...
# Response 19: **Answer (the classic “tongue‑twister” version)**
# *A woodc...
# Response 16: The tongue‑twister has been turned into a little “science” f...
# Response 2: A woodchuck could chuck roughly **700 pounds of wood**—a pla...
# Response 4: The classic tongue‑twister goes: “**A woodchuck would chuck ...
# Response 24: **Request 24**
#
# > *Question:* How much wood could a woodchuc...
# Response 21: Classic “how‑much‑wood‑a‑woodchuck‑could‑chuck” riddles are ...
# Response 5: The line “How much wood would a wood‑chuck chuck if a wood‑c...
# Response 23: **Answer**
# The classic tongue‑twister has become almost sc...
# Response 22: **⚙️ Chatbot Rules**
# 1. **Neutral, respect, inclusive** – ...
